# %%
# read testcsv and remove user_id column and save it using pandas 
import pandas as pd
df = pd.read_csv('test.csv')
df.drop('user_id', axis=1, inplace=True)
df.to_csv('test.csv', index=False)

# %%
df
# Out:
#       id  cid                                              image
# 0   3583  962  ......
# 1   3584  962  ......
# 2   3586  962  ......
# 3   3587  962  ......
# 4   3588  962  ......
# ..   ...  ...                                                ...
# 95  3699  702  ......
# 96  3700  702  ......
# 97  3701  702  ......
# 98  3702  702  ......
# 99  3703  702  ......
#
# [100 rows x 3 columns]

# %%
# read from the same csv and read image (base64) column and decode it and save it as image with name as `cid`
import base64
import os
os.system("rm -r data")
os.mkdir('data')
df = pd.read_csv('test.csv')
for index, row in df.iterrows():
    imgdata = base64.b64decode(row['image'].split(",")[1])
    format = row['image'].split(";")[0].split("/")[1]
    filename = f"data/{row['cid']}_{row['id']}.{format}"
    with open(filename, "wb") as f:
        f.write(imgdata)
        print('image saved as', filename)
# Out:
# image saved as data/962_3583.png
# image saved as data/962_3584.png
# image saved as data/962_3586.png
# image saved as data/962_3587.png
# image saved as data/962_3588.png
# image saved as data/962_3589.png
# image saved as data/962_3590.png
# image saved as data/962_3591.png
# image saved as data/962_3592.png
# image saved as data/962_3593.png
# image saved as data/962_3594.png
# image saved as data/962_3595.png
# image saved as data/962_3596.png
# image saved as data/962_3597.png
# image saved as data/962_3598.png
# image saved as data/962_3599.png
# image saved as data/962_3600.png
# image saved as data/962_3601.png
# image saved as data/962_3602.png
# image saved as data/962_3603.png
# image saved as data/962_3604.png
# image saved as data/962_3605.png
# image saved as data/222_3606.png
# image saved as data/222_3607.png
# image saved as data/222_3608.png
# image saved as data/222_3609.png
# image saved as data/222_3610.png
# image saved as data/222_3611.png
# ...

# %%
# print all cids with no repeat
print("\n".join(df['cid'].unique().astype(str)))
# Out:
# 962
# 222
# 6337
# 180
# 702
# 11
# 643833
# 3301
# 6351
# 9250
# 174
# 753
# 313
# 280
# 750
# 712
# 177
# 6324
# 6325
# 7965
# 284
# 176
# 6326
# 7855

# %%
block_list = [962, 222, 313, 280]
# moeve all images with cid in block_list from data to block folder
try:
    os.mkdir('block')
except FileExistsError:
    os.system("mv block/* data")
for index, row in df.iterrows():
    if row['cid'] in block_list:
        os.system(f"mv data/{row['cid']}_{row['id']}.{format} block")
